# %%
import pandas as pd
import numpy as np

df = pd.read_csv("완료/미래유산 지오코딩2.csv", encoding='CP949')
df.head()
# Out:
#    category_id              course_name duration_time  order_number  \
# 0          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             3
# 1          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             0
# 2          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             1
# 3          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             4
# 4          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             2
#
#              name district        address  price  image_url  page_url  \
# 0           해창양복점       중구   중구 남대문로7길 33    NaN        NaN       NaN
# 1           한영양복점       중구    중구 퇴계로20길 2    NaN        NaN       NaN
# 2  상동교회(구 새로나백화점)       중구     중구 남대문로 30    NaN        NaN       NaN
# 3           라 칸티나       중구      중구 을지로 19    NaN        NaN       NaN
# 4           남대문시장       중구  중구 남대문시장4길 21    NaN        NaN       NaN
#
#    description  decimalLatitude  decimalLongitude
# 0          NaN        37.563796        126.980017
# ...

# %%
import geokakao as gk

# Convert addresses to coordinates and integrate into the DataFrame
gk.add_coordinates_to_dataframe(df, 'address')

# %%
df.head()
# Out:
#    category_id              course_name duration_time  order_number  \
# 0          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             3
# 1          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             0
# 2          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             1
# 3          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             4
# 4          NaN  시장부터 식사까지 경험하는 서울시민의 일상           3시간             2
#
#              name district        address  price  image_url  page_url  \
# 0           해창양복점       중구   중구 남대문로7길 33    NaN        NaN       NaN
# 1           한영양복점       중구    중구 퇴계로20길 2    NaN        NaN       NaN
# 2  상동교회(구 새로나백화점)       중구     중구 남대문로 30    NaN        NaN       NaN
# 3           라 칸티나       중구      중구 을지로 19    NaN        NaN       NaN
# 4           남대문시장       중구  중구 남대문시장4길 21    NaN        NaN       NaN
#
#    description   decimalLatitude  decimalLongitude
# 0          NaN   37.563795833192  126.980017014113
# ...

# %%
# DataFrame을 CSV 파일로 저장 (인덱스 포함, utf-8 인코딩)
df.to_csv('완료/미래유산 지오코딩2.csv', index=True, encoding='CP949')
