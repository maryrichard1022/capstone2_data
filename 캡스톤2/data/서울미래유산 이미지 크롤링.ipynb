# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib.request

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("서울시 책방(서점) 현황정보.csv", encoding='CP949')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.read_csv("서울시 책방(서점) 현황정보.csv", encoding='CP949')
#       4 df.head()
#
# File c:\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
place_name = df["name"]
place_name.tolist()
place_name = place_name[50:]
place_name
# Out:
# 50           교보문고(목동점)
# 51     교보문고(수유 바로드림센터)
# 52       교보문고(신논현역스토어)
# 53          교보문고(영등포점)
# 54     교보문고(은평 바로드림센터)
#             ...
# 577               황룡서점
# 578               황룡서점
# 579                흙서점
# 580               흥인서점
# 581               희망문고
# Name: name, Length: 532, dtype: object

# %%
place_name = df2["name"]
place_name.tolist()
place_name = place_name[50:]
place_name


from selenium.common.exceptions import NoSuchElementException
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
browser_path = 'C:/Users/김가연/Desktop/23-2학기/캡스톤2/chromedriver.exe'
browser = webdriver.Chrome(browser_path)
browser.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")

for selected_place_name in place_name:
    selected_district = df.loc[df["name"] == selected_place_name, "district"].values[0]
    elem = browser.find_element_by_name("q")
    elem.clear()
    elem.send_keys(selected_district + " " + selected_place_name)
    elem.send_keys(Keys.RETURN)
    time.sleep(2)
    
    try:
        browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[0].click()
        time.sleep(1.5)
        find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
        print(selected_place_name, "의 첫번째 시도 : ", find_image_url)
        response = input("이미지를 사용하시겠습니까? (Y/N): ")
        if response.upper() == 'N':
            raise NoSuchElementException("이미지 요소를 찾을 수 없음")
        elif response.upper() == 'Y':
            df.loc[df['name'] == selected_place_name, 'image_url'] = find_image_url

    except NoSuchElementException:
        try:
            browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[1].click()
            time.sleep(2)
            find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
            print(selected_place_name, "의 두번째 시도 : ", find_image_url)
            response = input("이미지를 사용하시겠습니까? (Y/N): ")
            if response.upper() == 'N':
                raise NoSuchElementException("이미지 요소를 찾을 수 없음")
            elif response.upper() == 'Y':
                df.loc[df['name'] == selected_place_name, 'image_url'] = find_image_url
        except NoSuchElementException:
            print(selected_place_name, "이미지 요소를 찾을 수 없음")
# Out:
# 교보문고(목동점) 의 첫번째 시도 :  https://mblogthumb-phinf.pstatic.net/MjAxODAxMTdfMjcw/MDAxNTE2MTE2NzMwNjgy.unx-XOGWaGgJx6ga02jiWqnRwddbLnYbN4YQAAMC4gQg.m98obkSmTbI2V7LmrcSOlpGtx-Mk9mJa977qn0jPkZog.JPEG.dymt73/049_%EA%B5%90%EB%B3%B4%EB%AC%B8%EA%B3%A0%EB%AA%A9%EB%8F%99.jpg?type=w800
# 교보문고(목동점) 의 두번째 시도 :  https://image.kyobobook.co.kr/newimages/giftshop_new/work/1510/1492504202933_030017_01.jpg
# 교보문고(목동점) 이미지 요소를 찾을 수 없음
# 교보문고(수유 바로드림센터) 의 첫번째 시도 :  https://mblogthumb-phinf.pstatic.net/MjAyMTExMDdfNjIg/MDAxNjM2Mjg2NTA1NTQx.rbcr5mLI45JasxUG8A--d3UJSb6Ieg6Zyk9rA7u_iR8g.UxQW-OicuA3Q7grUtmeeAD8TjxMy1gnNTSxThoHIVWkg.JPEG.digitalhippy/SE-01dac053-eda7-40c1-82d5-2cd614511953.jpg?type=w800
# 교보문고(신논현역스토어) 이미지 요소를 찾을 수 없음
# 교보문고(영등포점) 의 두번째 시도 :  https://contents.kyobobook.co.kr/etc/storeinfo/map/map_36_big.gif
# 교보문고(영등포점) 이미지 요소를 찾을 수 없음
# ...

# %%
from selenium.common.exceptions import NoSuchElementException
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser_path = 'C:/Users/김가연/Desktop/23-2학기/캡스톤2/chromedriver.exe'

# 웹 드라이버 생성
browser = webdriver.Chrome(browser_path)
browser.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")Ny



for selected_place_name in place_name:
    selected_district = df.loc[df["name"] == selected_place_name, "district"].values[0]
    #print(selected_district)

    elem = browser.find_element_by_name("q")
    elem.clear()
    elem.send_keys(selected_district + " " + selected_place_name)
    elem.send_keys(Keys.RETURN)
    time.sleep(2)
    try:
        browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[0].click()
        time.sleep(1.5)
        find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
        print(selected_place_name, "의 첫번째 시도 : ", find_image_url)
        response = input("이미지를 사용하시겠습니까? (Y/N): ")
        if response.upper() == 'N':
            raise NoSuchElementException("이미지 요소를 찾을 수 없음")
        
        elif response.upper() == 'Y':
            df.loc[df['name'] == selected_place_name, 'image_url'] = find_image_url


    except NoSuchElementException:
        try:
            browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[1].click()
            time.sleep(2)
            find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
            print(selected_place_name, "의 두번째 시도 : ", find_image_url)
            response = input("이미지를 사용하시겠습니까? (Y/N): ")
            if response.upper() == 'N':
                raise NoSuchElementException("이미지 요소를 찾을 수 없음")
            elif response.upper() == 'Y':
                df.loc[df['name'] == selected_place_name, 'image_url'] = find_image_url
        except NoSuchElementException:
            print(selected_place_name, "이미지 요소를 찾을 수 없음")

# %%
df.head()
# Out:
#    category_id                name district                     address  \
# 0          NaN                1984      마포구            마포구 동교로 194 혜원빌딩
# 1          NaN              21세기문고      강남구            강남구 남부순환로359길 31
# 2          NaN               C&S서점      강남구  강남구 남부순환로 2806 군인공제회관 지하1층
# 3          NaN  Foreign book store      용산구               용산구 녹사평대로 208
# 4          NaN                PRNT      동작구              동작구 만양로1길 1 1층
#
#     latitude   longitude  work_time price    phone_number  \
# 0  37.557385  126.922886        NaN    무료     02-325-1984
# 1  37.486833  127.035565        NaN    무료  02-3463-1880
# 2  37.489109  127.052914        NaN    무료    02-2190-2178
# 3  37.536246  126.987227        NaN    무료     02-793-8249
# 4  37.505733  126.946737        NaN    무료   070-4177-0021
#
#                                            image_url  \
# 0  https://bookshopmap.s3.ap-northeast-2.amazonaw...
# 1                                                NaN
# ...

# %%
# DataFrame을 CSV 파일로 저장 (인덱스 포함, utf-8 인코딩)
df.to_csv("서울시 책방(서점) 현황정보 이미지 업데이트234.csv", index=True, encoding='CP949')

# %%
df2 = df[df["image_url"].isna()]
df2
# Out:
#      category_id        name district                       address  \
# 1            NaN      21세기문고      강남구              강남구 남부순환로359길 31
# 4            NaN        PRNT      동작구                동작구 만양로1길 1 1층
# 19           NaN        거목서점      서초구            서초구 신반포로 213 지하 9호
# 21           NaN        건영문고      노원구             노원구 섬밭로 258 지하 1층
# 23           NaN        경희문고     동대문구                  동대문구 회기로 113
# ..           ...         ...      ...                           ...
# 545          NaN        한미서적      송파구  송파구 문정동 156번지 가든파이브라이프 영관 4층
# 554          NaN  햇빛문고 푸른마을점      양천구               양천구 신정로11길 50-2
# 561          NaN        현대서적      강남구                  강남구 압구정로 201
# 562          NaN        현대서점      노원구            노원구 한글비석로 231 지하1층
# 567          NaN     형제할인책문고     영등포구       영등포구 당산로 95 현대아파트 지하 1층
#
#       latitude   longitude  work_time price    phone_number image_url  \
# 1    37.486833  127.035565        NaN    무료  02-3463-1880         NaN
# ...

# %%
place_name = df2["name"]
place_name.tolist()
place_name
# Out:
# 1          21세기문고
# 4            PRNT
# 19           거목서점
# 21           건영문고
# 23           경희문고
#           ...
# 545          한미서적
# 554    햇빛문고 푸른마을점
# 561          현대서적
# 562          현대서점
# 567       형제할인책문고
# Name: name, Length: 167, dtype: object

# %%
from selenium.common.exceptions import NoSuchElementException
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser_path = 'C:/Users/김가연/Desktop/23-2학기/캡스톤2/chromedriver.exe'

# 웹 드라이버 생성
browser = webdriver.Chrome(browser_path)
browser.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")



for selected_place_name in place_name:
    selected_district = df2.loc[df2["name"] == selected_place_name, "district"].values[0]
    #print(selected_district)

    elem = browser.find_element_by_name("q")
    elem.clear()
    elem.send_keys(selected_district + " " + selected_place_name)
    elem.send_keys(Keys.RETURN)
    time.sleep(2)
    try:
        browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[2].click()
        time.sleep(1.5)
        find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
        print(selected_place_name, "의 첫번째 시도 : ", find_image_url)
        response = input("이미지를 사용하시겠습니까? (Y/N): ")
        if response.upper() == 'N':
            raise NoSuchElementException("이미지 요소를 찾을 수 없음")
        
        elif response.upper() == 'Y':
            df2.loc[df2['name'] == selected_place_name, 'image_url'] = find_image_url


    except NoSuchElementException:
        try:
            browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[3].click()
            time.sleep(2)
            find_image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
            print(selected_place_name, "의 두번째 시도 : ", find_image_url)
            response = input("이미지를 사용하시겠습니까? (Y/N): ")
            if response.upper() == 'N':
                raise NoSuchElementException("이미지 요소를 찾을 수 없음")
            elif response.upper() == 'Y':
                df2.loc[df2['name'] == selected_place_name, 'image_url'] = find_image_url
        except NoSuchElementException:
            print(selected_place_name, "이미지 요소를 찾을 수 없음")
# Out:
# 21세기문고 의 첫번째 시도 :  https://contents.kyobobook.co.kr/sih/fit-in/400x0/pdt/9788995154731.jpg
# PRNT 이미지 요소를 찾을 수 없음
# 거목서점 의 첫번째 시도 :  https://payback.seocholib.or.kr/resources/images/20230810.jpg
# 건영문고 이미지 요소를 찾을 수 없음
# 경희문고 의 두번째 시도 :  https://mblogthumb-phinf.pstatic.net/MjAxNzA5MThfMTI4/MDAxNTA1Njk2OTMyMTI3.n6gIJ0OO__BkWck5nzaPWnwhpVOd4hwv9KN7_DnIkwEg.iKOaNSxxep5gKh9OrgISlm_E4VvTCaN2xHG_rG7h58wg.JPEG.kongram0305/20170827_175135.jpg?type=w420
# 계성문고 의 첫번째 시도 :  https://pds.joongang.co.kr/news/component/htmlphoto_mmdata/201902/04/3a1ae24d-1c56-4400-897e-f3fdeca44b7c.jpg
# 고려서점 의 첫번째 시도 :  https://mblogthumb-phinf.pstatic.net/MjAxNzExMTlfMTc3/MDAxNTExMTAwODE4MDMx.xbrGXx6va5KSivqLcAZ6UEEn-AvWncNTFyiF5IRNnRwg.h-jP8aYm-MZp9g9rJ8MACsjCudFfsg_CmqnbVYHTNPMg.JPEG.medaci/1511053694538.jpg?type=w800
# ...

# %%
df2.head()

# DataFrame을 CSV 파일로 저장 (인덱스 포함, utf-8 인코딩)
df2.to_csv("서울시 책방 이미지 결측치 채우기.csv", index=True, encoding='CP949')

# %%
# import pandas as pd
# import numpy as np
# df = pd.read_csv("서울시 서울미래유산 체험 코스 정제.csv", encoding='CP949')
# df.head()
# Out:
#    체험코스 아이디  category_id              course_name            name district  \
# 0       227          NaN  시장부터 식사까지 경험하는 서울시민의 일상           해창양복점       중구
# 1       227          NaN  시장부터 식사까지 경험하는 서울시민의 일상           한영양복점       중구
# 2       227          NaN  시장부터 식사까지 경험하는 서울시민의 일상  상동교회(구 새로나백화점)       중구
# 3       227          NaN  시장부터 식사까지 경험하는 서울시민의 일상           라 칸티나       중구
# 4       227          NaN  시장부터 식사까지 경험하는 서울시민의 일상           남대문시장       중구
#
#          address duration_time  order_number        x 좌표        y 좌표  \
# 0   중구 남대문로7길 33           3시간             3  126.980015  126.980015
# 1    중구 퇴계로20길 2           3시간             0  126.985436  126.985436
# 2     중구 남대문로 30           3시간             1  126.979047  126.979047
# 3      중구 을지로 19           3시간             4  126.979956  126.979956
# 4  중구 남대문시장4길 21           3시간             2  126.977284  126.977284
#
#    work_time price  phone_number  Unnamed: 13  image_url  page_url  \
# ...

# %%
df1 = pd.read_csv("서울시 책방(서점) 현황정보 이미지 크롤링 완료본.csv", encoding='CP949')
df1.head()
# Out:
#    category_id                name district                     address  \
# 0          NaN                1984      마포구            마포구 동교로 194 혜원빌딩
# 1          NaN              21세기문고      강남구            강남구 남부순환로359길 31
# 2          NaN               C&S서점      강남구  강남구 남부순환로 2806 군인공제회관 지하1층
# 3          NaN  Foreign book store      용산구               용산구 녹사평대로 208
# 4          NaN                PRNT      동작구              동작구 만양로1길 1 1층
#
#     latitude   longitude  work_time price    phone_number  \
# 0  37.557385  126.922886        NaN    무료     02-325-1984
# 1  37.486833  127.035565        NaN    무료  02-3463-1880
# 2  37.489109  127.052914        NaN    무료    02-2190-2178
# 3  37.536246  126.987227        NaN    무료     02-793-8249
# 4  37.505733  126.946737        NaN    무료   070-4177-0021
#
#                                            image_url  \
# 0  https://bookshopmap.s3.ap-northeast-2.amazonaw...
# 1                                                NaN
# ...

# %%
df2 = pd.read_csv("서울시 책방 이미지 결측치 채우기.csv", encoding='CP949')
df2.head()
# Out:
#    Unnamed: 0  category_id    name district             address   latitude  \
# 0           1          NaN  21세기문고      강남구    강남구 남부순환로359길 31  37.486833
# 1           4          NaN    PRNT      동작구      동작구 만양로1길 1 1층  37.505733
# 2          19          NaN    거목서점      서초구  서초구 신반포로 213 지하 9호  37.507271
# 3          21          NaN    건영문고      노원구   노원구 섬밭로 258 지하 1층  37.639110
# 4          23          NaN    경희문고     동대문구        동대문구 회기로 113  37.591650
#
#     longitude  work_time price    phone_number image_url  \
# 0  127.035565        NaN    무료  02-3463-1880         NaN
# 1  126.946737        NaN    무료   070-4177-0021       NaN
# 2  127.007271        NaN    무료    02-3476-1585       NaN
# 3  127.064915        NaN    무료     02-949-2148       NaN
# 4  127.049310        NaN    무료     02-957-7799       NaN
#
#                                   SNS url               page_url  description  \
# 0                                     NaN                    NaN          NaN
# ...

# %%
df.head()
# Out:
#    category_id                name district                     address  \
# 0          NaN                1984      마포구            마포구 동교로 194 혜원빌딩
# 1          NaN              21세기문고      강남구            강남구 남부순환로359길 31
# 2          NaN               C&S서점      강남구  강남구 남부순환로 2806 군인공제회관 지하1층
# 3          NaN  Foreign book store      용산구               용산구 녹사평대로 208
# 4          NaN                PRNT      동작구              동작구 만양로1길 1 1층
#
#     latitude   longitude  work_time price    phone_number  \
# 0  37.557385  126.922886        NaN    무료     02-325-1984
# 1  37.486833  127.035565        NaN    무료  02-3463-1880
# 2  37.489109  127.052914        NaN    무료    02-2190-2178
# 3  37.536246  126.987227        NaN    무료     02-793-8249
# 4  37.505733  126.946737        NaN    무료   070-4177-0021
#
#                                            image_url  \
# 0  https://bookshopmap.s3.ap-northeast-2.amazonaw...
# 1                                                NaN
# ...

# %%
# place_name = df["name"]
# place_name.tolist()
# place_name
# Out:
# 0               해창양복점
# 1               한영양복점
# 2      상동교회(구 새로나백화점)
# 3               라 칸티나
# 4               남대문시장
#             ...
# 108              국립극장
# 109          장충동 족발골목
# 110             장충체육관
# 111            장충테니스장
# 112           장충리틀야구장
# Name: name, Length: 113, dtype: object

# %%
# from selenium.common.exceptions import NoSuchElementException
# import time
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys

# browser_path = 'C:/Users/김가연/Desktop/23-2학기/캡스톤2/chromedriver.exe'

# # 웹 드라이버 생성
# browser = webdriver.Chrome(browser_path)
# browser.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")

# for selected_place_name in place_name:
#     elem = browser.find_element_by_name("q")
#     elem.clear()
#     elem.send_keys("서울 ", selected_place_name)
#     elem.send_keys(Keys.RETURN)
#     time.sleep(3)
    
#     try:
#         browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[0].click()
#         time.sleep(3)
#         image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
#         print(selected_place_name, "첫번째 : ", image_url)
#         df.loc[df['name'] == selected_place_name, 'image_url'] = image_url
#     except:
#         try:
#             browser.find_elements_by_css_selector(".rg_i.Q4LuWd")[1].click()
#             time.sleep(3)
#             image_url = browser.find_element_by_css_selector(".sFlh5c.pT0Scc.iPVvYb").get_attribute("src")
#             print(selected_place_name, "두번째 : ", image_url)
#             df.loc[df['name'] == selected_place_name, 'image_url'] = image_url
#         except NoSuchElementException:
#             print(selected_place_name, " 이미지 요소를 찾을 수 없음")
# Out:
# 해창양복점 첫번째 :  https://korean.visitseoul.net/comm/getImage?srvcId=POST&parentSn=28057&fileTy=POSTTHUMB&fileNo=1
# 한영양복점 첫번째 :  https://minio.nculture.org/amsweb-opt/multimedia_assets/13/97889/115285/c/%EC%84%9C%EC%9A%B8-%ED%95%9C%EC%98%81%EC%96%91%EB%B3%B5%EC%A0%90_%EC%83%81%EC%9D%98-%288%29_rev-full-size.jpg
# 상동교회(구 새로나백화점) 첫번째 :  https://mblogthumb-phinf.pstatic.net/MjAyMjEyMTJfMTc1/MDAxNjcwODU1MjY1MDk4.mBS-k3wvSAc_aAmNeQwW39JX7064OO9f_KvafQbDKfUg.EiKZh0oiAPBQWVrAYB_usmQSjyQkYvaWKpV_EXERinsg.JPEG.lee_myoungseob/20060712_01%EC%8B%9C49%EB%B6%8412%EC%B4%88_FinePix_F10.jpg?type=w800
# 라 칸티나 첫번째 :  https://mblogthumb-phinf.pstatic.net/MjAxOTExMDhfMjkz/MDAxNTczMjA1NzIwNjcx.ausnIcsMJlew8NXfJklISGvwmIUUuuyfQErInNNxF8Ig.EWcKQrckciIGCHgPU4n5-oJBx6nCUbkPS_s8oqVypGgg.JPEG.lisso1234/1573205719566.jpg?type=w800
# 남대문시장 첫번째 :  https://i.namu.wiki/i/OonJs0GXSXZkKn3Teio7YNAtq_8Jx5P4CHUK_CZufC7KDa7sIZRKeGbsBtI_zN-AyMaB3ZxG1SDFexXInw7SRA.webp
# ...

# %%
# # DataFrame을 CSV 파일로 저장 (인덱스 포함, utf-8 인코딩)
# df.to_csv("서울시 서울미래유산 체험 코스 정제 업데이트.csv", index=True, encoding='CP949')
